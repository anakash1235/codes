# %%
import matplotlib.pyplot as plt
import pandas as pd
import tensorflow as tf
import seaborn as sns
from tensorflow.keras.models import Model
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from keras import Sequential
sns.set
import numpy as np
from tensorflow.keras import layers, losses

# %%
df = pd.read_csv('http://storage.googleapis.com/download.tensorflow.org/data/ecg.csv', header=None)
raw_data = df.values
df.head(10)
# Out:
#         0         1         2         3         4         5         6    \
# 0 -0.112522 -2.827204 -3.773897 -4.349751 -4.376041 -3.474986 -2.181408
# 1 -1.100878 -3.996840 -4.285843 -4.506579 -4.022377 -3.234368 -1.566126
# 2 -0.567088 -2.593450 -3.874230 -4.584095 -4.187449 -3.151462 -1.742940
# 3  0.490473 -1.914407 -3.616364 -4.318823 -4.268016 -3.881110 -2.993280
# 4  0.800232 -0.874252 -2.384761 -3.973292 -4.338224 -3.802422 -2.534510
# 5 -1.507674 -3.574550 -4.478011 -4.408275 -3.321242 -2.105171 -1.481048
# 6 -0.297161 -2.766635 -4.102185 -4.589669 -4.219357 -3.650443 -2.300518
# 7  0.446769 -1.507397 -3.187468 -4.507462 -4.604201 -3.636115 -2.311604
# 8  0.087631 -1.753490 -3.304473 -4.704657 -4.686415 -3.611817 -2.267268
# 9 -0.832281 -1.700368 -2.257301 -2.853671 -2.853301 -2.701487 -2.285726
#
#         7         8         9    ...       131       132       133       134  \
# 0 -1.818286 -1.250522 -0.477492  ...  0.792168  0.933541  0.796958  0.578621
# 1 -0.992258 -0.754680  0.042321  ...  0.538356  0.656881  0.787490  0.724046
# 2 -1.490659 -1.183580 -0.394229  ...  0.886073  0.531452  0.311377 -0.021919
# 3 -1.671131 -1.333884 -0.965629  ...  0.350816  0.499111  0.600345  0.842069
# 4 -1.783423 -1.594450 -0.753199  ...  1.148884  0.958434  1.059025  1.371682
# 5 -1.301362 -0.498240 -0.286928  ...  1.089068  0.983369  1.014124  0.952629
# 6 -1.293917 -1.065658 -0.490520  ...  0.581779  0.684406  0.911651  0.979483
# 7 -1.597727 -1.362450 -0.669216  ...  1.001306  1.292059  1.378667  1.014765
# 8 -1.570893 -1.417790 -0.500788  ...  1.709046  2.142926  2.393528  1.925550
# 9 -1.555512 -1.266622 -1.085957  ...  2.110504  2.203668  2.227544  2.171733
#
#         135       136       137       138       139  140
# 0  0.257740  0.228077  0.123431  0.925286  0.193137  1.0
# 1  0.555784  0.476333  0.773820  1.119621 -1.436250  1.0
# 2 -0.713683 -0.532197  0.321097  0.904227 -0.421797  1.0
# 3  0.952074  0.990133  1.086798  1.403011 -0.383564  1.0
# 4  1.277392  0.960304  0.971020  1.614392  1.421456  1.0
# 5  0.749326  1.007076  1.634990  1.493365 -0.783134  1.0
# 6  1.053458  0.974787  1.110407  1.288165 -0.823386  1.0
# 7  0.820793  1.034388  1.258433  0.961215 -0.999476  1.0
# 8  1.027624  0.573453  0.192971 -0.648683 -2.441068  1.0
# 9  2.045938  2.126372  2.126852  1.679299  0.965814  1.0
#
# [10 rows x 141 columns]

# %%
labels = raw_data[:, -1]

data = raw_data[:, 0:-1]

train_data,test_data, train_labels,test_labels = train_test_split(data, labels, test_size = 0.2, random_state=21)

# %%
normal_train_data = train_data[train_labels] 
normal_test_data = test_data[test_labels] 

anamalous_train_data = train_data[~train_labels] 
anamalous_test_data = test_data[~test_labels]

# %%
plt.plot(np.arange(140),normal_train_data[0])
#plt.title('A normal ecg')
plt.show()

# %%
plt.plot(np.arange(140),anamalous_train_data[0])
plt.title('A anamalous ecg')
plt.show()

# %%
class AnomalyDetector(Model):
  def __init__(self): 
    super(AnomalyDetector,self).__init__()
    self.encoder=Sequential([
        layers.Dense(32,activation='relu'),
        layers.Dense(16,activation='relu'),
        layers.Dense(8,activation='relu')

    ])
    self.decoder=tf.keras.Sequential([ 
        layers.Dense(32,activation='relu'),
        layers.Dense(32,activation='relu'),
        layers.Dense(140,activation='sigmoid')
        
    ])

  def call(self,x):
    encoded=self.encoder(x)
    decoded=self.decoder(encoded)
    return decoded

autoencoder=AnomalyDetector()
#------------------------------------------------------------------------------

autoencoder.compile(optimizer='adam',loss='mae',metrics=['accuracy'])

#------------------------------------------------------------------------------

history=autoencoder.fit(normal_train_data,normal_train_data,
                        epochs=20,
                        batch_size=512,
                        validation_data=(normal_test_data,normal_test_data),
                        shuffle=True)
#plotting
plt.plot(history.history['loss'],label='Training loss')
plt.plot(history.history['val_loss'],label='Testing loss')
plt.legend()
plt.show() 
#---------------------------------------------------------------------------

reconstructions=autoencoder.predict(normal_train_data)
train_loss=tf.keras.losses.mae(reconstructions,normal_train_data)
plt.hist(train_loss[:],bins=50)

#plt.xlabel('Train loss')
#plt.ylabel('no of egs')
plt.show()
#-----------------------------------------------------------------------------

threshold=np.mean(train_loss)+np.std(train_loss)
print("threshold:",threshold)

#----------------------------------------------------------------------------
# Out:
# Epoch 1/20
# 5/5 [==============================] - 1s 38ms/step - loss: 0.7652 - accuracy: 0.0000e+00 - val_loss: 0.7607 - val_accuracy: 0.0000e+00
# Epoch 2/20
# 5/5 [==============================] - 0s 8ms/step - loss: 0.7574 - accuracy: 4.2391e-04 - val_loss: 0.7491 - val_accuracy: 0.0000e+00
# Epoch 3/20
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7429 - accuracy: 0.0106 - val_loss: 0.7279 - val_accuracy: 0.0286
# Epoch 4/20
# 5/5 [==============================] - 0s 9ms/step - loss: 0.7172 - accuracy: 0.0259 - val_loss: 0.6935 - val_accuracy: 0.0286
# Epoch 5/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.6783 - accuracy: 0.0242 - val_loss: 0.6467 - val_accuracy: 0.0179
# Epoch 6/20
# 5/5 [==============================] - 0s 8ms/step - loss: 0.6289 - accuracy: 0.0110 - val_loss: 0.5939 - val_accuracy: 0.0143
# Epoch 7/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5771 - accuracy: 0.0106 - val_loss: 0.5466 - val_accuracy: 0.0143
# Epoch 8/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5348 - accuracy: 0.0106 - val_loss: 0.5157 - val_accuracy: 0.0143
# Epoch 9/20
# 5/5 [==============================] - 0s 11ms/step - loss: 0.5112 - accuracy: 0.0106 - val_loss: 0.5032 - val_accuracy: 0.0143
# Epoch 10/20
# 5/5 [==============================] - 0s 9ms/step - loss: 0.5029 - accuracy: 0.0106 - val_loss: 0.5001 - val_accuracy: 0.0143
# Epoch 11/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5000 - accuracy: 0.0106 - val_loss: 0.4968 - val_accuracy: 0.0143
# Epoch 12/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4967 - accuracy: 0.0106 - val_loss: 0.4947 - val_accuracy: 0.0143
# Epoch 13/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4952 - accuracy: 0.0106 - val_loss: 0.4935 - val_accuracy: 0.0143
# Epoch 14/20
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4941 - accuracy: 0.0106 - val_loss: 0.4932 - val_accuracy: 0.0143
# Epoch 15/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4935 - accuracy: 0.0106 - val_loss: 0.4921 - val_accuracy: 0.0143
# Epoch 16/20
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4926 - accuracy: 0.0110 - val_loss: 0.4916 - val_accuracy: 0.0143
# Epoch 17/20
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4920 - accuracy: 0.0110 - val_loss: 0.4911 - val_accuracy: 0.0143
# Epoch 18/20
# 5/5 [==============================] - 0s 8ms/step - loss: 0.4915 - accuracy: 0.0110 - val_loss: 0.4904 - val_accuracy: 0.0143
# Epoch 19/20
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4908 - accuracy: 0.0110 - val_loss: 0.4897 - val_accuracy: 0.0143
# Epoch 20/20
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4901 - accuracy: 0.0110 - val_loss: 0.4887 - val_accuracy: 0.0143
# 74/74 [==============================] - 0s 1ms/step
# threshold: 0.5635090084250923
